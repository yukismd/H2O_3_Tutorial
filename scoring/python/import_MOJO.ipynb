# %% [markdown]
# ## MOJOモデルのインポートとスコアリングの実施
# https://docs.h2o.ai/h2o/latest-stable/h2o-docs/save-and-load-model.html

# %%
import h2o

h2o.__version__
# Out:
# '3.36.0.4'

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "11.0.9" 2020-10-20 LTS; Java(TM) SE Runtime Environment 18.9 (build 11.0.9+7-LTS); Java HotSpot(TM) 64-Bit Server VM 18.9 (build 11.0.9+7-LTS, mixed mode)
#   Starting server from /opt/anaconda3/lib/python3.8/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/50/glkvvhjx03g22fwy2r0tgylr0000gn/T/tmpjdx5xo2o
#   JVM stdout: /var/folders/50/glkvvhjx03g22fwy2r0tgylr0000gn/T/tmpjdx5xo2o/h2o_YShimada_MBP16_started_from_python.out
#   JVM stderr: /var/folders/50/glkvvhjx03g22fwy2r0tgylr0000gn/T/tmpjdx5xo2o/h2o_YShimada_MBP16_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# ...
# --------------------------  -------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Asia/Tokyo
# ...

# %%
# Import MOJO model
model = h2o.upload_mojo('../mojo_model/gbm_6f3364e8_bbbb_4130_ad11_f2cd44e0a106.zip', model_id='imported_mojo_model')
# Out:
# generic Model Build progress: |██████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  imported_mojo_model
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0               50.0                      50.0              20261.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        5.0        5.0         5.0        15.0        32.0        27.58
# ModelMetricsBinomialGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.12662236916578856
# RMSE: 0.35584037034292293
# LogLoss: 0.4072442075266401
# Mean Per-Class Error: 0.2712940233858492
# AUC: 0.8094376111365491
# AUCPR: 0.6163425058469529
# Gini: 0.6188752222730982
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.2521713444777117:
#                 0       1   Error               Rate
# 0      0  19834.0  3530.0  0.1511   (3530.0/23364.0)
# ...

# %%
type(model)
# Out:
# h2o.estimators.generic.H2OGenericEstimator

# %%
# Data for scoring
frame = h2o.import_file('../../data/UCI_Credit_Card3_head.csv')
frame
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# ...

# %%
# Scoring
model.predict(frame)
# Out:
# generic prediction progress: |███████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">      p0</th><th style="text-align: right;">      p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.285838</td><td style="text-align: right;">0.714162</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.637386</td><td style="text-align: right;">0.362614</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.89056 </td><td style="text-align: right;">0.10944 </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.848642</td><td style="text-align: right;">0.151358</td></tr>
# ...

# %%
# Shapley Scoring
model.predict_contributions(frame)
# Out:
# contributions progress: |████████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# ...
